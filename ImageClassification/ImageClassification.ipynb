# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
image_path = 'Gateway_of_India.jpg'

# %%
image = Image.open(image_path)

# %%
plt.imshow(image)
plt.title("Uploaded Image")
plt.axis("off")
plt.show()

# %%
image_array = np.array(image)

# %%
image_array.shape
# Out:
# (1280, 1280, 3)

# %%
image_array
# Out:
# array([[[ 62, 144, 244],
#         [ 59, 141, 241],
#         [ 59, 141, 241],
#         ...,
#         [ 94, 163, 240],
#         [ 94, 163, 240],
#         [ 93, 162, 239]],
#
#        [[ 63, 145, 245],
#         [ 62, 144, 244],
#         [ 62, 144, 244],
#         ...,
#         [ 95, 164, 241],
#         [ 94, 163, 240],
#         [ 94, 163, 240]],
#
#        [[ 62, 144, 244],
#         [ 64, 146, 246],
#         [ 64, 146, 246],
#         ...,
#         [ 95, 164, 241],
#         [ 95, 164, 241],
#         [ 95, 164, 241]],
#
#        ...,
#
#        [[158, 143, 124],
#         [169, 154, 133],
#         [128, 113,  92],
#         ...,
#         [174, 173, 171],
#         [151, 147, 146],
#         [154, 153, 149]],
#
#        [[165, 147, 135],
#         [160, 142, 128],
#         [165, 147, 133],
#         ...,
#         [138, 135, 130],
#         [145, 140, 136],
#         [180, 177, 172]],
#
#        [[164, 146, 136],
#         [158, 140, 130],
#         [147, 129, 117],
#         ...,
#         [102,  97,  93],
#         [ 65,  60,  54],
#         [ 81,  76,  70]]], shape=(1280, 1280, 3), dtype=uint8)

# %%
print(f"Minimum Pixel Value {np.min(image_array)}")
print(f"Maximum Pixel Value {np.max(image_array)}")
# Out:
# Minimum Pixel Value 0
# Maximum Pixel Value 255

# %%
# First 5 rows in each color channel

image_array[ : 5 , : 5 , : ]
# Out:
# array([[[ 62, 144, 244],
#         [ 59, 141, 241],
#         [ 59, 141, 241],
#         [ 63, 145, 245],
#         [ 63, 145, 245]],
#
#        [[ 63, 145, 245],
#         [ 62, 144, 244],
#         [ 62, 144, 244],
#         [ 63, 145, 245],
#         [ 64, 146, 246]],
#
#        [[ 62, 144, 244],
#         [ 64, 146, 246],
#         [ 64, 146, 246],
#         [ 63, 145, 245],
#         [ 63, 145, 245]],
#
#        [[ 61, 143, 243],
#         [ 64, 146, 246],
#         [ 64, 146, 246],
#         [ 61, 143, 243],
#         [ 61, 143, 243]],
#
#        [[ 61, 143, 243],
#         [ 64, 146, 246],
#         [ 64, 146, 246],
#         [ 61, 143, 243],
#         [ 62, 144, 244]]], dtype=uint8)

# %%
plt.imshow(image_array)
plt.axis("off")
plt.title("Image in Numpy Array Format")
plt.show()
