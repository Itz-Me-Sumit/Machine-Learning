# %%
import matplotlib.pyplot as plt
x = ["Mon" , "Tue" , "Wed" , "Thu" , "Fri" , "Sat" , "Sun"] # X-axis
y = [23,21,7,15,8,34,20]
plt.plot(x,y)
plt.title("Sales Per Day")
plt.xlabel("Days")
plt.ylabel("Sales")
plt.show()
