# %%
import pandas as pd

dataset = pd.read_csv(r"loan.csv")
dataset.head(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       3 dataset = pd.read_csv(r"loan.csv")
#       4 dataset.head(3)
#
# File c:\Users\sumit\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\__init__.py:56
#      46 from pandas._config import (
#      47     get_option,
#      48     set_option,
#    (...)     52     options,
#      53 )
#      55 # let init-time option registration happen
# ---> 56 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
#      58 from pandas.core.api import (
#      59     # dtype
#      60     ArrowDtype,
#    (...)    119     DataFrame,
#     120 )
#     121 from pandas.core.col import col
#
# File c:\Users\sumit\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\config_init.py:31
#      19 import pandas._config.config as cf
# ...
