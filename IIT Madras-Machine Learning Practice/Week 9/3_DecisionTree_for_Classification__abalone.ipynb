# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

# %%
column_names = ['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight', 'Viscera weight', 'Shell weight', 'Rings']
abalone_data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/abalone/abalone.data', header=None, names=column_names)

# %%
abalone_data.head(10)
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
# 5   I   0.425     0.300   0.095        0.3515          0.1410          0.0775
# 6   F   0.530     0.415   0.150        0.7775          0.2370          0.1415
# 7   F   0.545     0.425   0.125        0.7680          0.2940          0.1495
# 8   M   0.475     0.370   0.125        0.5095          0.2165          0.1125
# 9   F   0.550     0.440   0.150        0.8945          0.3145          0.1510
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7
# 5         0.120      8
# 6         0.330     20
# 7         0.260     16
# 8         0.165      9
# 9         0.320     19

# %%
abalone_data.hist(bins=50 , figsize=(15,15))
plt.show()

# %%
sns.pairplot(abalone_data , diag_kind="hist")
plt.show()

# %%
sns.heatmap(abalone_data.iloc[ : , :-1].select_dtypes(include="number").corr() , annot=True , square=True)
plt.show()

# %%
sns.boxplot(data=abalone_data.iloc[:, :- 1], orient="h", palette="Set2")
plt.show()

# %%
abalone_data["Rings"].unique()
# Out:
# array([15,  7,  9, 10,  8, 20, 16, 19, 14, 11, 12, 18, 13,  5,  4,  6, 21,
#        17, 22,  1,  3, 26, 23, 29,  2, 27, 25, 24])

# %%
abalone_data["Rings"].value_counts().sort_index()
# Out:
# Rings
# 1       1
# 2       1
# 3      15
# 4      57
# 5     115
# 6     259
# 7     391
# 8     568
# 9     689
# 10    634
# 11    487
# 12    267
# 13    203
# 14    126
# 15    103
# 16     67
# 17     58
# 18     42
# 19     32
# 20     26
# 21     14
# 22      6
# 23      9
# 24      2
# 25      1
# 26      1
# 27      2
# 29      1
# Name: count, dtype: int64

# %%
print((abalone_data["Height"] == 0).sum())
# Out:
# 2

# %%
abalone_data[abalone_data["Height"] == 0]
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 1257   I   0.430      0.34     0.0         0.428          0.2065
# 3996   I   0.315      0.23     0.0         0.134          0.0575
#
#       Viscera weight  Shell weight  Rings
# 1257          0.0860        0.1150      8
# 3996          0.0285        0.3505      6

# %%
means = pd.pivot_table(abalone_data , index = ["Sex"] , aggfunc = {"Height":np.mean})
means
# Out:
#        Height
# Sex
# F    0.158011
# I    0.107996
# M    0.151381

# %%
x = abalone_data.iloc[: , :-1]
y = abalone_data.iloc[: , -1]

# %%
x.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight
# 0         0.150
# 1         0.070
# 2         0.210
# 3         0.155
# 4         0.055

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size=0.2 , random_state=0)

# %% [markdown]
# #### Pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler , OneHotEncoder
from sklearn.tree import DecisionTreeClassifier

# %%
numeric_features = ['Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight', 'Viscera weight', 'Shell weight']
categorical_features = ["Sex"]

# %%
numeric_transformer = Pipeline([
    ("imputer" , SimpleImputer(missing_values=0 , strategy="constant" , fill_value=0.107996)),
    ("scaler" , StandardScaler())
])

# %%
categorical_transformer = OneHotEncoder(handle_unknown="ignore")

# %%
preprocessor = ColumnTransformer([
    ("num" , numeric_transformer , numeric_features),
    ("cat" , categorical_transformer , categorical_features)
])

# %%
clf = Pipeline([
    ("preprocessor" , preprocessor),
    ("classifier" , DecisionTreeClassifier(
        max_depth=3 , random_state=42
    ))
])

# %%
clf.fit(x_train , y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value=0.107996,
#                                                                                  missing_values=0,
#                                                                                  strategy='constant')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Length', 'Diameter',
#                                                    'Height', 'Whole weight',
#                                                    'Shucked weight',
#                                                    'Viscera weight',
#                                                    'Shell weight']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Sex'])])),
#                 ('classifier',
#                  DecisionTreeClassifier(max_depth=3, random_state=42))])

# %%
y_pred = clf.predict(x_test)

# %%
y_pred_reshaped = y_pred.reshape(len(y_pred) , 1)
y_test_reshaped = y_test.values.reshape(len(y_test) , 1)

# %%
comparision = np.concatenate((y_pred_reshaped , y_test_reshaped) , axis=1)
comparision
# Out:
# array([[10, 13],
#        [ 8,  8],
#        [10, 11],
#        ...,
#        [ 7,  7],
#        [10, 17],
#        [ 4,  4]], shape=(836, 2))

# %%
for each in comparision:
    print(each)
# Out:
# [10 13]
# [8 8]
# [10 11]
# [4 5]
# [10 12]
# [10 11]
# [9 7]
# [8 8]
# [7 7]
# [10  9]
# [7 8]
# [5 8]
# [ 9 11]
# [8 9]
# [5 4]
# [10  7]
# [9 7]
# [10 17]
# [10  7]
# [7 7]
# [7 7]
# [7 5]
# [8 8]
# [9 9]
# [10 10]
# [10 10]
# [4 5]
# [11 15]
# [ 8 10]
# [10 14]
# [9 8]
# [4 4]
# [10  9]
# [11 13]
# [7 7]
# [8 7]
# [7 8]
# [10  9]
# [7 8]
# [10 11]
# [ 8 15]
# [ 8 12]
# [ 8 17]
# [10 16]
# [10 11]
# [ 8 11]
# [9 8]
# [10 10]
# [10 11]
# [7 6]
# [10 13]
# [7 7]
# [ 9 13]
# [11 20]
# [ 8 12]
# [9 7]
# [5 8]
# [ 9 10]
# [7 7]
# [7 7]
# [10  9]
# [9 9]
# [ 9 11]
# [7 8]
# [7 7]
# [11 12]
# [11 13]
# [10 17]
# [8 8]
# [11 12]
# [8 9]
# [11 17]
# [10 10]
# [8 6]
# [ 8 11]
# [8 8]
# [10  8]
# [8 9]
# [10  8]
# [8 8]
# [10  8]
# [5 6]
# [7 7]
# [10 13]
# [ 8 11]
# [7 6]
# [10  9]
# [11 12]
# [4 5]
# [7 6]
# [ 9 11]
# [ 8 11]
# [9 8]
# [7 7]
# [10 16]
# [5 8]
# [ 8 11]
# [9 8]
# [10 18]
# [10 11]
# [10 12]
# [ 8 14]
# [10 12]
# [10 11]
# [5 6]
# [10  9]
# [7 7]
# [7 6]
# [ 7 11]
# [10 11]
# [11 11]
# [11 12]
# [ 8 20]
# [ 9 10]
# [10 14]
# [11 10]
# [10 10]
# [10 12]
# [5 4]
# [ 8 12]
# [7 7]
# [10 13]
# [7 6]
# [8 8]
# [10 17]
# [10 15]
# [10  9]
# [10 11]
# [7 7]
# [10 11]
# [10  8]
# [9 7]
# [8 7]
# [10 10]
# [11 11]
# [10  9]
# [ 8 10]
# [8 9]
# [7 8]
# [11 16]
# [ 8 16]
# [ 8 13]
# [7 6]
# [9 9]
# [10 10]
# [9 9]
# [8 8]
# [7 8]
# [7 8]
# [11  9]
# [9 7]
# [10  9]
# [9 6]
# [7 7]
# [ 9 11]
# [10 11]
# [10 11]
# [9 8]
# [ 8 11]
# [7 6]
# [ 8 22]
# [ 7 10]
# [8 9]
# [11 17]
# [10 14]
# [7 7]
# [9 7]
# [ 7 16]
# [9 9]
# [8 8]
# [ 7 13]
# [10 10]
# [ 8 12]
# [8 8]
# [11 11]
# [11 12]
# [10  9]
# [10 14]
# [9 9]
# [10 11]
# [10  9]
# [4 3]
# [ 8 14]
# [ 8 10]
# [7 7]
# [8 7]
# [5 6]
# [7 7]
# [9 7]
# [8 9]
# [10  9]
# [7 7]
# [8 6]
# [8 9]
# [9 7]
# [10 10]
# [10 10]
# [11 10]
# [ 8 11]
# [ 9 10]
# [10 11]
# [10 19]
# [8 8]
# [5 5]
# [8 6]
# [10 11]
# [7 5]
# [7 8]
# [9 8]
# [10  9]
# [ 8 13]
# [7 5]
# [7 7]
# [9 9]
# [10 11]
# [ 9 12]
# [7 7]
# [10 17]
# [4 4]

# %%
from sklearn.metrics import ConfusionMatrixDisplay
cm_matrix = ConfusionMatrixDisplay.from_predictions(y_test , y_pred , values_format=".5g")

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         5
#            4       0.26      0.45      0.33        11
#            5       0.38      0.42      0.40        33
#            6       0.00      0.00      0.00        47
#            7       0.41      0.57      0.48        98
#            8       0.21      0.38      0.27       113
#            9       0.21      0.19      0.20       127
#           10       0.20      0.46      0.28       107
#           11       0.16      0.15      0.16        95
#           12       0.00      0.00      0.00        66
#           13       0.00      0.00      0.00        39
#           14       0.00      0.00      0.00        26
#           15       0.00      0.00      0.00        18
#           16       0.00      0.00      0.00        14
#           17       0.00      0.00      0.00        10
#           18       0.00      0.00      0.00         5
#           19       0.00      0.00      0.00         8
#           20       0.00      0.00      0.00         8
#           21       0.00      0.00      0.00         2
#           22       0.00      0.00      0.00         1
#           23       0.00      0.00      0.00         2
#           29       0.00      0.00      0.00         1
#
#     accuracy                           0.25       836
#    macro avg       0.08      0.12      0.10       836
# weighted avg       0.17      0.25      0.20       836
# c:\Users\sumit\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\sumit\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\sumit\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
from sklearn.model_selection import cross_val_score,ShuffleSplit
scores = cross_val_score(
    clf,
    x_train,
    y_train,
    cv=ShuffleSplit(test_size=0.2,n_splits=10,random_state=42)
)

# %%
print(f"Accuracy : {(scores.mean()*100):.3f}%")
# Out:
# Accuracy : 25.082%

# %%
from sklearn import tree

#plt the figure, setting a black background
plt.figure(figsize=(48,8), facecolor ='w')

#create the tree plot
a = tree.plot_tree(
    clf['classifier'],
    #use the feature names stored
    feature_names = column_names,
    rounded = True,
    filled = True,
    fontsize=12
)

#show the plot
plt.show()

# %%
x_train_new = preprocessor.fit_transform(x_train)

# %%
from sklearn.model_selection import GridSearchCV

tuned_parameters = [{
    "max_depth": list(range(1,10)),
    "min_samples_split": list(range(2,11,2))
}]

clf_cv = GridSearchCV(
    DecisionTreeClassifier(),
    tuned_parameters,
    scoring="recall_macro",
)

clf_cv.fit(x_train_new,y_train)
# Out:
# c:\Users\sumit\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_split.py:813: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# c:\Users\sumit\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\sumit\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\sumit\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\sumit\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\sumit\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\sumit\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\sumit\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\sumit\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\sumit\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\sumit\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\sumit\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\sumit\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\sumit\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\sumit\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\sumit\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\sumit\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\sumit\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\sumit\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\sumit\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\sumit\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\sumit\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\sumit\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\sumit\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\sumit\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\sumit\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid=[{'max_depth': [1, 2, 3, 4, 5, 6, 7, 8, 9],
#                           'min_samples_split': [2, 4, 6, 8, 10]}],
#              scoring='recall_macro')

# %%
best_clf = clf_cv.best_estimator_

# %%
best_clf.fit(x_train_new , y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)
