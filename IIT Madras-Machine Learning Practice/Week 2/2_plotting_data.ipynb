# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv'
df = pd.read_csv(data_url , sep=";")

# %%
sns.set()
df.quality.hist()
plt.title("Wine: Quality VS Count")
plt.xlabel("Wine Quality")
plt.ylabel("Number of same wive Quality")
# Out:
# Text(0, 0.5, 'Number of same wive Quality')

# %%
# My approach

wine_quality = df.groupby("quality").size()
plt.figure(figsize=(12,8))
plt.bar(wine_quality.index , wine_quality.values)
plt.title("Wine: Quality Vs Count")
plt.xlabel("Wine Quality")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')
