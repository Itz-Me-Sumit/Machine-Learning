# %%
from sklearn.model_selection import StratifiedShuffleSplit
import pandas as pd

data_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv'
df = pd.read_csv(data_url , sep=";")

features = df.drop("quality",axis=1)
label = df["quality"]

split = StratifiedShuffleSplit(n_splits=1 , test_size=0.2 , random_state=42) # Define karta hai ki data ko kaise split karna hai !!

for train_index , test_index in split.split(features,label):
    strat_train_set = df.loc[train_index]
    strat_test_set = df.loc[test_index]

# %%
wine_feature = strat_train_set.drop("quality" , axis=1)
wine_label = strat_train_set["quality"].copy()

# %% [markdown]
# ### Missing values
# * to handle missing values
#     * imputation technique to fill up missing values
#         * in sklearn we use simpleimputer to fill missing values with say , median , mean etc
#
#     * drop that rows containing missing values
#         * dropna() , drop() -> it'll drop rows containing missig values

# %%
wine_feature.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy="median") # strategy can be median , mean etc

# Before fit and transform we have to drop all columns which doesn't contains numeric values

""""
we can do it like

imputer.fit(wine_feature) # it'll first find median for all columns
imputer.transform(wine_feature) # it'll replace all NaN to median

"""

result = imputer.fit_transform(wine_feature)

# %%
imputer.statistics_
wine_feature.median()

imputer_wineFeatures_comparision = pd.DataFrame({
    "Imputer" : imputer.statistics_,
    "data_Median" : wine_feature.median()
})

imputer_wineFeatures_comparision # Both will be same
# Out:
#                        Imputer  data_Median
# fixed acidity          7.90000      7.90000
# volatile acidity       0.52000      0.52000
# citric acid            0.26000      0.26000
# residual sugar         2.20000      2.20000
# chlorides              0.08000      0.08000
# free sulfur dioxide   14.00000     14.00000
# total sulfur dioxide  39.00000     39.00000
# density                0.99675      0.99675
# pH                     3.31000      3.31000
# sulphates              0.62000      0.62000
# alcohol               10.20000     10.20000
